# %% [raw]
# Recipe for Potion of transformation:
# rabbit_foot:  6
# cat_hair: 2
# dragon_scale: raise rabbit_foot to the power of cat_hair
# fire_slug: Divide rabbit_foot by cat_hair, then add cat hair
# bat_wing: Subtract two rabbit_feet from dragon_scale and subtract one fire_slug
#
# Hint: to raise a number to a power, use "**". For example, to raise x to the y, you write x**y

# %%
# Creating variables for all of your ingredients
rabbit_foot = 6
cat_hair = 2
 
## Enter code here:
dragon_scale = 36
fire_slug = 5
bat_wing = 19
 
## check to see if your code is correct
import run_test as test
test.potion4(rabbit_foot, cat_hair, dragon_scale, fire_slug, bat_wing)
# Out:
# rabbit_foot properly defined
# cat_hair properly defined
# dragon_scale properly defined
# fire_slug properly defined
# bat_wing properly defined
# Fantastic job! You successfully created the Potion of Transformation!
