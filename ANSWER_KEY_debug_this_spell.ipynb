# %% [markdown]
# # What is debugging?
# Virtually everytime you right code you will make a mistake. One of the most common mistakes you'll make when writing code are typos. Although these mistakes are usually easy to fix, they're sometimes  very tricky to spot! In this module we'll learn how to use our knowledge of python rules, or **syntax** and built in **error messages** to debug our code.

# %% [markdown]
# # Your task:
# Find and fix the bugs in the following code. Your goal is to produce a potion with the following ingredients:
#
# *   5 frog eggs
# *   3 pheonix feathers
# *   10 mole whiskers
# *   1 worm
# *   3 elderberries
# *   1 mountain mist
#
#
#
#
#
# If you have completed your task correctly, a magic potion will apperar.

# %%
# run this to import test
import run_test as test
# Out:
#      <input type="file" id="files-5f6faca1-ac92-439e-9e2b-11652ad18f1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f6faca1-ac92-439e-9e2b-11652ad18f1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving run_test.py to run_test.py
# Saving potion.jpg to potion.jpg

# %%
# correct code

frog_eggs = 5
pheonix_feathers = 3 # error: underscore missing from variable name
mole_whiskers = 10 # error: wrong amount of mole whiskers was added
worm = 1
elderberries = 3
mountain_mist = 1


cauldron = frog_eggs + pheonix_feathers + mole_whiskers + worm + elderberries + mountain_mist # error: forgot to add the worm


test.debug(cauldron)
# Out:
# You did it! Great job finding all of the bugs!
